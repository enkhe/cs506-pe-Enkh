# %%
# Import necessary libraries
import pandas as pd

wineReview = pd.read_csv('./PE04_winereview.csv', encoding='utf-8');
wineReview.head(5)
wineReview.info()
wineReview.describe()
wineReview.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
import matplotlib.pyplot as plt

wineReview['points'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Frequency of Wine Review Scores')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram with a bin size of 10
wineReview['points'].hist(bins=10, color='skyblue', edgecolor='black', rwidth=0.8)
plt.title('Frequency of Wine Review Scores (Bin Size: 10)')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram with a bin size of 10
wineReview['points'].hist(bins=10, color='skyblue', edgecolor='black', rwidth=0.8)
plt.title('Frequency of Wine Review Scores (Bin Size: 10)')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram with a bin size of 3
wineReview['points'].hist(bins=3, color='skyblue', edgecolor='black', rwidth=0.8)
plt.title('Frequency of Wine Review Scores (Bin Size: 3)')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram with a bin size of 3
# wineReview['points'].hist(bins=3, color='skyblue', edgecolor='black', rwidth=0.8)
# plt.title('Frequency of Wine Review Scores (Bin Size: 3)')
# plt.xlabel('Points')
# plt.ylabel('Frequency')
# plt.show()

def plot_histograms(bin_sizes):
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('Wine Review Scores with Different Bin Sizes', fontsize=16)
    axes = axes.flatten()

    for i, bins in enumerate(bin_sizes):
        ax = axes[i]
        hist_data = wineReview['points'].value_counts(bins=bins, sort=False)
        wineReview['points'].hist(bins=bins, color='skyblue', edgecolor='black', rwidth=0.8, ax=ax)
        ax.set_title(f'Bin Size: {bins}')
        ax.set_xlabel('Points')
        ax.set_ylabel('Frequency')

        # Annotate histogram bars with their values
        for rect in ax.patches:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Call the function with desired bin sizes
plot_histograms([2, 3, 6, 10])

# %%
# Plot histogram for the price column with different bin sizes
def plot_price_histograms(bin_sizes):
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('Wine Prices with Different Bin Sizes', fontsize=16)
    axes = axes.flatten()

    for i, bins in enumerate(bin_sizes):
        ax = axes[i]
        price_data.hist(bins=bins, color='skyblue', edgecolor='black', rwidth=0.8, ax=ax)
        ax.set_title(f'Bin Size: {bins}')
        ax.set_xlabel('Price')
        ax.set_ylabel('Frequency')

        # Annotate histogram bars with their values
        for rect in ax.patches:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Call the function with desired bin sizes
plot_price_histograms([5, 10, 20, 50])

# %%
# Plot histogram for the price column with different bin sizes
def plot_price_histograms(bin_sizes):
    # Extract price data from wineReview DataFrame
    price_data = wineReview['price'].dropna()  # Drop NaN values to avoid errors

    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('Wine Prices with Different Bin Sizes', fontsize=16)
    axes = axes.flatten()

    for i, bins in enumerate(bin_sizes):
        ax = axes[i]
        price_data.hist(bins=bins, color='skyblue', edgecolor='black', rwidth=0.8, ax=ax)
        ax.set_title(f'Bin Size: {bins}')
        ax.set_xlabel('Price')
        ax.set_ylabel('Frequency')

        # Annotate histogram bars with their values
        for rect in ax.patches:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Call the function with desired bin sizes
plot_price_histograms([5, 10, 20, 50])

# %%
# Plot histogram for the price column with different bin sizes
def plot_price_histograms(bin_sizes):
    # Extract price data from wineReview DataFrame
    price_data = wineReview['price'].dropna()  # Drop NaN values to avoid errors

    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('Wine Prices with Different Bin Sizes', fontsize=16)
    axes = axes.flatten()

    for i, bins in enumerate(bin_sizes):
        ax = axes[i]
        price_data.hist(bins=bins, color='skyblue', edgecolor='black', rwidth=0.8, ax=ax)
        ax.set_title(f'Bin Size: {bins}')
        ax.set_xlabel('Price')
        ax.set_ylabel('Frequency')

        # Annotate histogram bars with their values
        for rect in ax.patches:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width() / 2, height, f'{int(height)}', ha='center', va='bottom')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Call the function with desired bin sizes
plot_price_histograms([5, 10, 20, 50])

# %%
price_data = wineReview['price'].dropna() 
price_data.hist(bins=20, color='skyblue', edgecolor='black', rwidth=0.8)
plt.title('Distribution of Wine Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
price_data = wineReview['price'].dropna() 
# price_data
# plt.figure(figsize=(10, 6))
# plt.boxplot(price_data, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
# plt.title('Box Plot of Wine Prices')
# plt.xlabel('Price')
# plt.show()

# Display summary statistics for the price column
print("Summary Statistics for Price Column:")
print(price_data.describe())

# Plot a boxplot and histogram side by side for better visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Summary Statistics for Price Column', fontsize=16)
# Boxplot
axes[0].boxplot(price_data, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
axes[0].set_title('Box Plot of Wine Prices')
axes[0].set_xlabel('Price')

# Histogram
price_data.hist(bins=50, color='skyblue', edgecolor='black', ax=axes[1])
axes[1].set_title('Histogram of Wine Prices')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Summary Statistics for Price Column:
# count    120975.000000
# mean         35.363389
# std          41.022218
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64

# %%
price_data = wineReview['price'].dropna() 

# Remove outliers using the IQR method
Q1 = price_data.quantile(0.25)
Q3 = price_data.quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
price_data_cleaned = price_data[(price_data >= lower_bound) & (price_data <= upper_bound)]

# Display the cleaned data
price_data_cleaned.describe()
# Out:
# count    113734.000000
# mean         29.113695
# std          16.173909
# min           4.000000
# 25%          16.000000
# 50%          25.000000
# 75%          39.000000
# max          79.000000
# Name: price, dtype: float64

# %%
# Display summary statistics for the price column
print("Summary Statistics for Price Column:")
print(price_data.describe())

# Plot a boxplot and histogram side by side for better visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Summary Statistics for Price Column - Mid Range Data', fontsize=16)

# Boxplot
axes[0].boxplot(price_data_cleaned, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
axes[0].set_title('Box Plot of Wine Prices')
axes[0].set_xlabel('Price')

# Histogram
price_data_cleaned.hist(bins=50, color='skyblue', edgecolor='black', ax=axes[1])
axes[1].set_title('Histogram of Wine Prices')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Summary Statistics for Price Column:
# count    120975.000000
# mean         35.363389
# std          41.022218
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64
